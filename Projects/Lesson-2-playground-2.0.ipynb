# %% [markdown]
# ## Football fouls Classifier

# %%
from fastai.vision.all import *
from utils import *

# %%
path = Path.cwd()/'datasets/football_foul'

if not path.exists(): path.mkdir()

# %%
key = ""

# %%
results = search_images_bing(key, 'football fouls')
ims = results.attrgot('contentUrl')
len(ims)
# Out:
# 150

# %%
dest = path/'show.jpg'
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128, 128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x65 at 0x7FD6E6069810>

# %%
download_images(path, urls=ims)

# %%
fns = get_image_files(path)

# %%
fns[2]
# Out:
# Path('/home/fastai-2020-lalkrishna/My-files/datasets/football_foul/00000016.jpg')

# %%
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink)
# Out:
# (#0) []

# %% [markdown]
# ### Loading data

# %%
fouls = DataBlock(
    blocks = (ImageBlock, CategoryBlock),
    get_items = get_image_files,
    splitter = RandomSplitter(valid_pct=.2, seed=42),
    get_y = parent_label,
    item_tfms = Resize(300)
)

# %%
dls = fouls.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
from fastai.vision.widgets import ImageClassifierCleaner
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('football_foul',), value='football_foul'), Dropdown(options=('Train', 'Valid'…
